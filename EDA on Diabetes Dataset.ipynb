# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('E:\\Artificial Intelligence\\Artificial Intelligence in HINDI\\All-in-OneMachine Learning,DL,NLP,AWS Deply [Hindi][Python]\\4. Data Preprocessing\\pima-data.csv')
df
# Out:
#      num_preg  glucose_conc  diastolic_bp  thickness  insulin   bmi  \
# 0           6           148            72         35        0  33.6
# 1           1            85            66         29        0  26.6
# 2           8           183            64          0        0  23.3
# 3           1            89            66         23       94  28.1
# 4           0           137            40         35      168  43.1
# ..        ...           ...           ...        ...      ...   ...
# 763        10           101            76         48      180  32.9
# 764         2           122            70         27        0  36.8
# 765         5           121            72         23      112  26.2
# 766         1           126            60          0        0  30.1
# 767         1            93            70         31        0  30.4
#
#      diab_pred  age    skin  diabetes
# 0        0.627   50  1.3790      True
# 1        0.351   31  1.1426     False
# ...

# %%
df.isnull().sum()
# Out:
# num_preg        0
# glucose_conc    0
# diastolic_bp    0
# thickness       0
# insulin         0
# bmi             0
# diab_pred       0
# age             0
# skin            0
# diabetes        0
# dtype: int64

# %%
df.corr()
# Out:
#               num_preg  glucose_conc  diastolic_bp  thickness   insulin  \
# num_preg      1.000000      0.129459      0.141282  -0.081672 -0.073535
# glucose_conc  0.129459      1.000000      0.152590   0.057328  0.331357
# diastolic_bp  0.141282      0.152590      1.000000   0.207371  0.088933
# thickness    -0.081672      0.057328      0.207371   1.000000  0.436783
# insulin      -0.073535      0.331357      0.088933   0.436783  1.000000
# bmi           0.017683      0.221071      0.281805   0.392573  0.197859
# diab_pred    -0.033523      0.137337      0.041265   0.183928  0.185071
# age           0.544341      0.263514      0.239528  -0.113970 -0.042163
# skin         -0.081672      0.057328      0.207371   1.000000  0.436783
# diabetes      0.221898      0.466581      0.065068   0.074752  0.130548
#
#                    bmi  diab_pred       age      skin  diabetes
# num_preg      0.017683  -0.033523  0.544341 -0.081672  0.221898
# ...

# %%
import seaborn as sns

# %%
#Checking Multicollinearity
sns.heatmap(df.corr());

# %%
 del df['skin']

# %%
sns.heatmap(df.corr());

# %%
df.head(5)
# Out:
#    num_preg  glucose_conc  diastolic_bp  thickness  insulin   bmi  diab_pred  \
# 0         6           148            72         35        0  33.6      0.627
# 1         1            85            66         29        0  26.6      0.351
# 2         8           183            64          0        0  23.3      0.672
# 3         1            89            66         23       94  28.1      0.167
# 4         0           137            40         35      168  43.1      2.288
#
#    age  diabetes
# 0   50      True
# 1   31     False
# 2   32      True
# 3   21     False
# 4   33      True

# %%
#Hot-Encoding
diab_map = {True:1,False:0} 
df['diabetes'] = df['diabetes'].map(diab_map)
df.head(5)
# Out:
#    num_preg  glucose_conc  diastolic_bp  thickness  insulin   bmi  diab_pred  \
# 0         6           148            72         35        0  33.6      0.627
# 1         1            85            66         29        0  26.6      0.351
# 2         8           183            64          0        0  23.3      0.672
# 3         1            89            66         23       94  28.1      0.167
# 4         0           137            40         35      168  43.1      2.288
#
#    age  diabetes
# 0   50         1
# 1   31         0
# 2   32         1
# 3   21         0
# 4   33         1

# %%
x = df.drop('diabetes',axis=1)
y = df['diabetes']

# %%
#Training the dataset(70% to train and 30% to test)
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3,random_state = 42)

# %%
from sklearn.impute import SimpleImputer

fill_0 = SimpleImputer(missing_values=0, strategy="mean")
x_train = fill_0.fit_transform(x_train)
x_test = fill_0.fit_transform(x_test)

# %%
df1 = pd.read_csv('E:\\Artificial Intelligence\\Artificial Intelligence in HINDI\\All-in-OneMachine Learning,DL,NLP,AWS Deply [Hindi][Python]\\4. Data Preprocessing\\1.2 Data Preprocessing Code\\Data Preprocessing Code\\Data\\Data_Pre_Processing\\exams.csv')
df1.head(5)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0    male        group E          associate's degree      standard
# 1  female        group C          associate's degree  free/reduced
# 2    male        group D           bachelor's degree      standard
# 3  female        group A           bachelor's degree      standard
# 4  female        group D                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0               completed          79             75             81
# 1                    none          56             65             64
# 2                    none          86             68             74
# 3                    none          68             78             76
# 4                    none          49             68             61

# %%
#Feature Scaling for columns = [math score,reading score,writing score]
from sklearn import preprocessing

# %%
df1['math score'] = df1['math score'].astype(float)
df1['reading score'] = df1['reading score'].astype(float)
df1['writing score'] = df1['writing score'].astype(float)

# %%
df1['math score'] = preprocessing.scale(df1['math score'])
df1['reading score'] = preprocessing.scale(df1['reading score'])
df1['writing score'] = preprocessing.scale(df1['writing score'])

# %%
df1
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0     male        group E          associate's degree      standard
# 1   female        group C          associate's degree  free/reduced
# 2     male        group D           bachelor's degree      standard
# 3   female        group A           bachelor's degree      standard
# 4   female        group D                 high school  free/reduced
# ..     ...            ...                         ...           ...
# 95  female        group A             master's degree  free/reduced
# 96  female        group D                 high school  free/reduced
# 97  female        group C                some college      standard
# 98    male        group D            some high school      standard
# 99  female        group A             master's degree  free/reduced
#
#    test preparation course  math score  reading score  writing score
# 0                completed    0.994557       0.574138       1.049901
# ...

# %%
df_plot = df1[['math score','reading score','writing score']].copy()

# %%
#Visualization of Feature Scaling
df_plot.plot.kde();

# %%
#LabelEncoding(Used where there is some relationship between values in column)
le = preprocessing.LabelEncoder()
df1['gender'] = le.fit_transform(df1['gender'].astype(str)) #typecasting to covert from object into string for better

# %%
df1.head(5)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0       1        group E          associate's degree      standard
# 1       0        group C          associate's degree  free/reduced
# 2       1        group D           bachelor's degree      standard
# 3       0        group A           bachelor's degree      standard
# 4       0        group D                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0               completed    0.994557       0.574138       1.049901
# 1                    none   -0.646391      -0.169564      -0.178476
# 2                    none    1.493976       0.053547       0.544099
# 3                    none    0.209756       0.797248       0.688613
# 4                    none   -1.145810       0.053547      -0.395248

# %%
print(le.classes_)
# Out:
# ['female' 'male']

# %%
#One-HotEncoding(Used where there is no relationship between values in column)
df1 = pd.get_dummies(df1,columns=['race/ethnicity','race/ethnicity','lunch','test preparation course'])
df1.head(5)
# Out:
#    gender parental level of education  math score  reading score  \
# 0       1          associate's degree    0.994557       0.574138
# 1       0          associate's degree   -0.646391      -0.169564
# 2       1           bachelor's degree    1.493976       0.053547
# 3       0           bachelor's degree    0.209756       0.797248
# 4       0                 high school   -1.145810       0.053547
#
#    writing score  race/ethnicity_group A  race/ethnicity_group B  \
# 0       1.049901                       0                       0
# 1      -0.178476                       0                       0
# 2       0.544099                       0                       0
# 3       0.688613                       1                       0
# 4      -0.395248                       0                       0
#
#    race/ethnicity_group C  race/ethnicity_group D  race/ethnicity_group E  \
# 0                       0                       0                       1
# ...
